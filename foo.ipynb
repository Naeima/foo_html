# %% [markdown]
# <a href="https://colab.research.google.com/github/Naeima/foo_html/blob/main/foo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evaluating the Forest Observatory Ontology (FOO) with SPARQL Querries.

# %%
# Retrieve all classes in the ontology
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?class
WHERE {
  # ?class rdf:type owl:Class .
}
"""

# Execute the query
result = g.query(query)

# Print the results
for row in result:
    print(row)
# Out:
# (rdflib.term.URIRef('https://w3id.org/def/foo#Sensor'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Observation'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#ObservableProperty'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#FeatureOfInterest'),)

# %%
# Retrieve all classes in the ontology (Evaluate Latency)
import time
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?class
WHERE {
  # ?class rdf:type owl:Class .
}
"""

# Measure query execution time
start_time = time.time()
result = g.query(query)
end_time = time.time()
latency = end_time - start_time

# Define the expected results
expected_classes = set([
    # List all expected classes here, e.g.:
    "https://w3id.org/def/foo#Sensor",
    "https://w3id.org/def/foo#Observation",
    "https://w3id.org/def/foo#ObservableProperty",
    "https://w3id.org/def/foo#FeatureOfInterest",

    # ...
])

# Retrieve the actual results
retrieved_classes = set(str(row[0]) for row in result)

# Calculate precision and recall
true_positives = len(expected_classes & retrieved_classes)
precision = true_positives / len(retrieved_classes) if retrieved_classes else 0
recall = true_positives / len(expected_classes) if expected_classes else 0

# Print the results
print(f"Latency: {latency} seconds")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
# Out:
# Latency: 0.008919954299926758 seconds
# Precision: 1.0
# Recall: 1.0

# %%
# Retrieve all properties in the ontology
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?property
WHERE {
  # ?property rdf:type owl:ObjectProperty .
}

"""
# Execute the query
result = g.query(query)

# Print the results
for row in result:
    print(row)
# Out:
# (rdflib.term.URIRef('https://w3id.org/def/foo#hasFeatureOfInterest'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#isFeatureOfInterestOf'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#observes'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#isObservedBy'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#madeObservation'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#madeBySensor'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#observedProperty'),)

# %%
# Retrieve all properties in the ontology (Evaluate Latency)
import time
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?property
WHERE {
  # ?property rdf:type owl:ObjectProperty .
}
"""

# Measure query execution time
start_time = time.time()
result = g.query(query)
end_time = time.time()
latency = end_time - start_time

# Define the expected results
expected_properties = set([
    'https://w3id.org/def/foo#hasFeatureOfInterest',
    'https://w3id.org/def/foo#isFeatureOfInterestOf',
    'https://w3id.org/def/foo#observes',
    'https://w3id.org/def/foo#isObservedBy',
    'https://w3id.org/def/foo#madeObservation',
    'https://w3id.org/def/foo#madeBySensor',
    'https://w3id.org/def/foo#observedProperty'
])

# Retrieve the actual results
retrieved_properties = set(str(row[0]) for row in result)

# Calculate precision and recall
true_positives = len(expected_properties & retrieved_properties)
precision = true_positives / len(retrieved_properties) if retrieved_properties else 0
recall = true_positives / len(expected_properties) if expected_properties else 0

# Print the results
print(f"Latency: {latency} seconds")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
# Out:
# Latency: 0.007910728454589844 seconds
# Precision: 1.0
# Recall: 1.0

# %%
# Retrieve all instances of a specific class
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX foo: <https://w3id.org/def/foo#>

SELECT DISTINCT ?instance
WHERE {
  # ?instance rdf:type foo:Sensor .
}

"""
# Execute the query
result = g.query(query)

# Print the results
for row in result:
    print(row)
# Out:
# (rdflib.term.URIRef('https://w3id.org/def/foo#Kuma'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Jasmin'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Putut'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Bikang1'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Bikang2'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Sejati'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Umas2'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Ita'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Abaw'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Liun'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Dara'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Jasper'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Guli'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Maliau'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Tunglap'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Seri'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Puteri'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Tulid'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Kasih'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Aqeela'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Merotai'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#Binbingan'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#SoilSensor'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#CameraTrap'),)
# (rdflib.term.URIRef('https://w3id.org/def/foo#lianas'),)

# %%
# Retrieve all instances of a specific class (Evalaute Latency)
import time
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX foo: <https://w3id.org/def/foo#>

SELECT DISTINCT ?instance
WHERE {
  # ?instance rdf:type foo:Sensor .
}
"""

# Measure query execution time
start_time = time.time()
result = g.query(query)
end_time = time.time()
latency = end_time - start_time

# Define the expected results
expected_instances = set([
    'https://w3id.org/def/foo#Kuma',
    'https://w3id.org/def/foo#Jasmin',
    'https://w3id.org/def/foo#Putut',
    'https://w3id.org/def/foo#Bikang1',
    'https://w3id.org/def/foo#Bikang2',
    'https://w3id.org/def/foo#Sejati',
    'https://w3id.org/def/foo#Umas2',
    'https://w3id.org/def/foo#Ita',
    'https://w3id.org/def/foo#Abaw',
    'https://w3id.org/def/foo#Liun',
    'https://w3id.org/def/foo#Dara',
    'https://w3id.org/def/foo#Jasper',
    'https://w3id.org/def/foo#Guli',
    'https://w3id.org/def/foo#Maliau',
    'https://w3id.org/def/foo#Tunglap',
    'https://w3id.org/def/foo#Seri',
    'https://w3id.org/def/foo#Puteri',
    'https://w3id.org/def/foo#Tulid',
    'https://w3id.org/def/foo#Kasih',
    'https://w3id.org/def/foo#Aqeela',
    'https://w3id.org/def/foo#Merotai',
    'https://w3id.org/def/foo#Binbingan',
    'https://w3id.org/def/foo#SoilSensor',
    'https://w3id.org/def/foo#CameraTrap',
    'https://w3id.org/def/foo#lianas'
])

# Retrieve the actual results
retrieved_instances = set(str(row[0]) for row in result)

# Calculate precision and recall
true_positives = len(expected_instances & retrieved_instances)
precision = true_positives / len(retrieved_instances) if retrieved_instances else 0
recall = true_positives / len(expected_instances) if expected_instances else 0

# Print the results
print(f"Latency: {latency} seconds")
print(f"Precision: {precision}")
print(f"Recall: {recall}")

# Print the retrieved instances
for instance in retrieved_instances:
    print(instance)
# Out:
# Latency: 0.007700204849243164 seconds
# Precision: 1.0
# Recall: 1.0
# https://w3id.org/def/foo#Kasih
# https://w3id.org/def/foo#Tunglap
# https://w3id.org/def/foo#Binbingan
# https://w3id.org/def/foo#SoilSensor
# https://w3id.org/def/foo#Abaw
# https://w3id.org/def/foo#Bikang2
# https://w3id.org/def/foo#Umas2
# https://w3id.org/def/foo#Liun
# https://w3id.org/def/foo#Ita
# https://w3id.org/def/foo#Guli
# https://w3id.org/def/foo#Kuma
# https://w3id.org/def/foo#Jasper
# https://w3id.org/def/foo#Jasmin
# https://w3id.org/def/foo#Dara
# https://w3id.org/def/foo#Bikang1
# https://w3id.org/def/foo#Seri
# https://w3id.org/def/foo#lianas
# https://w3id.org/def/foo#Putut
# https://w3id.org/def/foo#Maliau
# https://w3id.org/def/foo#Aqeela
# https://w3id.org/def/foo#Puteri
# https://w3id.org/def/foo#Sejati
# https://w3id.org/def/foo#CameraTrap
# https://w3id.org/def/foo#Merotai
# https://w3id.org/def/foo#Tulid

# %%
# Retrieve all triples (subject-predicate-object) in the ontology
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
SELECT ?subject ?predicate ?object
WHERE {
  # ?subject ?predicate ?object .
}
LIMIT 100

"""
# Execute the query
result = g.query(query)

# Print the results
for row in result:
    print(row)
# Out:
# (rdflib.term.URIRef('https://w3id.org/def/foo#Tulid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Tulid', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Tunglap'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('https://w3id.org/def/foo#Sensor'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#LocalDate'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.Literal('The local date in Sabah, Malaysia, when the GPS collar records its readings.'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.Literal('Elephas maximus, commonly known as the Asian elephant, is a species of large mammal native to various regions in South and Southeast Asia, including India, Sri Lanka, Thailand, and parts of Indonesia. It is distinguished by its smaller ears compared to its African relatives, and it has a prominent domed head with two hemispherical bulges. The Asian elephant is classified as Endangered due to significant threats from habitat loss, fragmentation, and poaching. This species plays a crucial ecological role, aiding in forest maintenance through seed dispersal and the creation of clearings in dense vegetation.', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Observation'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.Literal('Act of carrying out an (Observation) Procedure to estimate or calculate a value of a property of a FeatureOfInterest (e.g., Elephant). Observation can be seen as a placeholder that links relevant information together. In our ontology, observation can be considered an ID for each data record.', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Distance'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Distance', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Bikang1'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Bikang 1', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Site'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# (rdflib.term.URIRef('https://github.com/Naeima'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/affiliation'), rdflib.term.Literal('Cardiff University', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Latitude'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('https://w3id.org/def/foo#Observation'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Bikang1'), rdflib.term.URIRef('https://w3id.org/def/foo#hasFeatureOfInterest'), rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#observedProperty'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'), rdflib.term.Literal('Relation linking an Observation to the property that was observed. The ObservableProperty should be a property of the FeatureOfInterest (linked by hasFeatureOfInterest) of this Observation.', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Liun'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Liun', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Kasih'), rdflib.term.URIRef('https://w3id.org/def/foo#hasFeatureOfInterest'), rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#GPSObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#Longitude'), rdflib.term.Literal('566.222302', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://w3id.org/def/foo#TotalN'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Site'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#sameAs'), rdflib.term.URIRef('http://www.w3.org/ns/sosa/observedProperty'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#madeBySensor'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('made by sensor', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#isObservedBy'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#ManisJavanica'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.Literal('Sunda pangolin aka Manis Javanica is a mammal distinguished by its protective armor of keratin scales, which cover its body except for its belly and face. Native to Southeast Asia, including Malaysia, Thailand, Indonesia, and Vietnam, this species is adapted to various habitats, ranging from primary and secondary forests to wetlands, mangroves, and grasslands. Characterized by its elongated body, small head, and long, prehensile tail, the Sunda pangolin is primarily nocturnal and has a diet mainly consisting of ants and termites, which it extracts using its long, sticky tongue. It plays a vital role in its ecosystem by controlling insect populations.', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#SoilObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#Sand'), rdflib.term.Literal('20.66', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Dara'), rdflib.term.URIRef('https://w3id.org/def/foo#observes'), rdflib.term.URIRef('https://w3id.org/def/foo#GPSObservation'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Maliau'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Maliau', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#madeBySensor'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#isDefinedBy'), rdflib.term.URIRef('http://www.w3.org/ns/sosa/'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#HDOP'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#isFeatureOfInterestOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('https://w3id.org/def/foo#FeatureOfInterest'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Altitude'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#LocalTime'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Local Time'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#GPSObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#Direction'), rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Seri'), rdflib.term.URIRef('https://w3id.org/def/foo#hasFeatureOfInterest'), rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Horizon'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#sameAs'), rdflib.term.URIRef('http://www.w3.org/ns/sosa/observedProperty'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#GPSObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#madeBySensor'), rdflib.term.URIRef('https://w3id.org/def/foo#Maliau'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#'), rdflib.term.URIRef('https://schema.org/citation'), rdflib.term.Literal('Cite this vocabulary as: Hamed, N., Rana, O., Goossens, B., Orozco-terWengel, P., Perera, C. (2023). FOO: An Upper-Level Ontology for the Forest Observatory. In: Pesquita, C., et al. The Semantic Web: ESWC 2023 Satellite Events. ESWC 2023. Lecture Notes in Computer Science, vol 13998. Springer, Cham. https://doi.org/10.1007/978-3-031-43458-7_29', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#observes'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'), rdflib.term.Literal('Relation between a Sensor and an ObservableProperty that it is capable of sensing.', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#lianasObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#treeNLianas'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Jasper'), rdflib.term.URIRef('https://w3id.org/def/foo#hasFeatureOfInterest'), rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#observedProperty'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('https://w3id.org/def/foo#ObservableProperty'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#ObservableProperty'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#sameAs'), rdflib.term.URIRef('http://www.w3.org/ns/sosa/ObservableProperty'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#MalayopythonReticulatus'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Malayopython reticulatus', lang='la'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#lianas'), rdflib.term.URIRef('https://w3id.org/def/foo#observes'), rdflib.term.URIRef('https://w3id.org/def/foo#TreeObservation'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#GPSObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#Longitude'), rdflib.term.Literal('565.222302', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://w3id.org/def/foo#isObservedBy'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#inverseOf'), rdflib.term.URIRef('https://w3id.org/def/foo#observes'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#lianasObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#treeIndividualNo'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Direction'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Direction'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Count'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.Literal('Observation count per data set.'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#'), rdflib.term.URIRef('http://purl.org/vocab/vann/preferredNamespaceUri'), rdflib.term.Literal('https://w3id.org/def/foo#'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Speed'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#TotalC'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#sameAs'), rdflib.term.URIRef('http://www.w3.org/ns/sosa/observedProperty'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#GPSObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#madeBySensor'), rdflib.term.URIRef('https://w3id.org/def/foo#Puteri'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#madeObservation'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('made observation', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#madeObservation'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'), rdflib.term.Literal('Relation between a Sensor and an Observation made by the Sensor.', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Puteri'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('https://w3id.org/def/foo#Sensor'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#SoilObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#Subplot'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Umas2'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('https://w3id.org/def/foo#Sensor'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Sejati'), rdflib.term.URIRef('https://w3id.org/def/foo#hasFeatureOfInterest'), rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#lianas'), rdflib.term.URIRef('https://w3id.org/def/foo#siteName'), rdflib.term.Literal('Danum W15'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Silt'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Longitude'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Longitude'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#HDOP'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Tunglap'), rdflib.term.URIRef('https://w3id.org/def/foo#observes'), rdflib.term.URIRef('https://w3id.org/def/foo#GPSObservation'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Jasmin'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Jasmin', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#lianasObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#treeDBH_cm'), rdflib.term.Literal('110', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/def/foo#madeBySensor'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'), rdflib.term.Literal('Relation between an Observation and the Sensor which made the Observation.', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Silt'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.Literal('silt content of the soil sample', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#ImageObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#ImageID'), rdflib.term.Literal('001'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Merotai'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Merotai', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Nasalislarvatus'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.Literal('Nasalis larvatus, aka the proboscis monkey, is a primate species endemic to the island of Borneo. Characterized by its large, pendulous nose in males, this arboreal monkey primarily inhabits mangrove forests, riverine, and coastal areas, and is known for its distinct vocalizations and swimming abilities.', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#lianasObservation'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Tree Observation', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Jasmin'), rdflib.term.URIRef('https://w3id.org/def/foo#hasFeatureOfInterest'), rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#CameraTrap'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Camera Trap', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#hasFeatureOfInterest'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'), rdflib.term.Literal('A relation between an Observation and the entity whose quality was observed, or between an Actuation and the entity whose property was modified, or between an act of Sampling and the entity that was sampled.', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Subplot'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.Literal('Number of the subplot sampled within each 1 Ha plot', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#'), rdflib.term.URIRef('http://purl.org/dc/elements/1.1/contributor'), rdflib.term.Literal('Benoit Goossens', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#LocalDate'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('https://w3id.org/def/foo#Observation'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Speed'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Horizon'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Horizon', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#GPSObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#GMTTime'), rdflib.term.Literal('22:40:35', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#time')))
# (rdflib.term.URIRef('https://w3id.org/def/foo#isFeatureOfInterestOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('https://w3id.org/def/foo#Observation'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Abaw'), rdflib.term.URIRef('https://w3id.org/def/foo#hasFeatureOfInterest'), rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('https://w3id.org/def/foo#FeatureOfInterest'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#MalayopythonReticulatus'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('https://w3id.org/def/foo#FeatureOfInterest'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Jasper'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Jasper', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#'), rdflib.term.URIRef('http://purl.org/dc/elements/1.1/contributor'), rdflib.term.Literal('Pablo Orozco-terWengel', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#madeBySensor'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('https://w3id.org/def/foo#Observation'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Liun'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('https://w3id.org/def/foo#Sensor'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Guli'), rdflib.term.URIRef('https://w3id.org/def/foo#hasFeatureOfInterest'), rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'), rdflib.term.Literal('Bornean elephants exhibit distinct morphological and behavioural traits compared to mainland Asian elephants, and their genetic uniqueness emphasises their priority for conservation efforts. Although they are considered an evolutionary significant unit requiring tailored conservation measures, their formal recognition as a subspecies awaits further research. Restricted to about 5% of Borneo, primarily in Sabah, Bornean elephants typically form family groups of 5 to 20 individuals, occasionally merging into larger herds of up to 200.', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Latitude'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#SoilObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#TotalP'), rdflib.term.Literal('263.74', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Silt'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Maliau'), rdflib.term.URIRef('https://w3id.org/def/foo#hasFeatureOfInterest'), rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#LandUse'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#GMTTime'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#time'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#'), rdflib.term.URIRef('http://www.w3.org/ns/prov#wasDerivedFrom'), rdflib.term.URIRef('https://ontology.forest-observatory.org'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#GPSObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#HDOP'), rdflib.term.Literal('1.14', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://w3id.org/def/foo#LandUse'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Land Use', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#GPSObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#madeBySensor'), rdflib.term.URIRef('https://w3id.org/def/foo#Kuma'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#TotalC'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('https://w3id.org/def/foo#Observation'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Dara'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Dara', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#PlotName'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.Literal('Name of the 1 Ha plot sampled', lang='en'))

# %%
# Retrieve all triples (subject-predicate-object) in the ontology (Evaluate latency)
import time
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
SELECT ?subject ?predicate ?object
WHERE {
  # ?subject ?predicate ?object .
}
LIMIT 50
"""

# Measure query execution time
start_time = time.time()
result = g.query(query)
end_time = time.time()
latency = end_time - start_time

# Define the expected results
expected_triples = set([
    ('https://w3id.org/def/foo#Tulid', 'http://www.w3.org/2000/01/rdf-schema#label', 'Tulid'),
    ('https://w3id.org/def/foo#Tunglap', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'https://w3id.org/def/foo#Sensor'),
    ('https://w3id.org/def/foo#LocalDate', 'http://www.w3.org/2004/02/skos/core#definition', 'The local date in Sabah, Malaysia, when the GPS collar records its readings.'),
    ('https://w3id.org/def/foo#ElephasMaximus', 'http://www.w3.org/2004/02/skos/core#definition', 'Elephas maximus, commonly known as the Asian elephant, is a species of large mammal native to various regions in South and Southeast Asia, including India, Sri Lanka, Thailand, and parts of Indonesia. It is distinguished by its smaller ears compared to its African relatives, and it has a prominent domed head with two hemispherical bulges. The Asian elephant is classified as Endangered due to significant threats from habitat loss, fragmentation, and poaching. This species plays a crucial ecological role, aiding in forest maintenance through seed dispersal and the creation of clearings in dense vegetation.'),
])

# Retrieve the actual results
retrieved_triples = set((str(row[0]), str(row[1]), str(row[2])) for row in result)

# Calculate precision and recall
true_positives = len(expected_triples & retrieved_triples)
precision = true_positives / len(retrieved_triples) if retrieved_triples else 0
recall = true_positives / len(expected_triples) if expected_triples else 0

# Print the results
print(f"Latency: {latency} seconds")
print(f"Precision: {precision}")
print(f"Recall: {recall}")

# Print the retrieved triples
for triple in retrieved_triples:
    print(triple)
# Out:
# Latency: 0.007967472076416016 seconds
# Precision: 0.08
# Recall: 1.0
# ('https://w3id.org/def/foo#lianasObservation', 'https://w3id.org/def/foo#treeIndividualNo', '2')
# ('https://w3id.org/def/foo#Tunglap', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'https://w3id.org/def/foo#Sensor')
# ('https://w3id.org/def/foo#LocalDate', 'http://www.w3.org/2004/02/skos/core#definition', 'The local date in Sabah, Malaysia, when the GPS collar records its readings.')
# ('https://w3id.org/def/foo#Tulid', 'http://www.w3.org/2000/01/rdf-schema#label', 'Tulid')
# ('https://w3id.org/def/foo#Site', 'http://www.w3.org/2000/01/rdf-schema#range', 'http://www.w3.org/2001/XMLSchema#string')
# ('https://w3id.org/def/foo#GPSObservation', 'https://w3id.org/def/foo#Longitude', '565.222302')
# ('https://w3id.org/def/foo#Latitude', 'http://www.w3.org/2000/01/rdf-schema#domain', 'https://w3id.org/def/foo#Observation')
# ('https://w3id.org/def/foo#Bikang1', 'https://w3id.org/def/foo#hasFeatureOfInterest', 'https://w3id.org/def/foo#ElephasMaximus')
# ('https://w3id.org/def/foo#GPSObservation', 'https://w3id.org/def/foo#Direction', '0')
# ('https://w3id.org/def/foo#', 'https://schema.org/citation', 'Cite this vocabulary as: Hamed, N., Rana, O., Goossens, B., Orozco-terWengel, P., Perera, C. (2023). FOO: An Upper-Level Ontology for the Forest Observatory. In: Pesquita, C., et al. The Semantic Web: ESWC 2023 Satellite Events. ESWC 2023. Lecture Notes in Computer Science, vol 13998. Springer, Cham. https://doi.org/10.1007/978-3-031-43458-7_29')
# ('https://w3id.org/def/foo#Distance', 'http://www.w3.org/2000/01/rdf-schema#label', 'Distance')
# ('https://w3id.org/def/foo#Kasih', 'https://w3id.org/def/foo#hasFeatureOfInterest', 'https://w3id.org/def/foo#ElephasMaximus')
# ('https://w3id.org/def/foo#observes', 'http://www.w3.org/2000/01/rdf-schema#comment', 'Relation between a Sensor and an ObservableProperty that it is capable of sensing.')
# ('https://w3id.org/def/foo#observedProperty', 'http://www.w3.org/2000/01/rdf-schema#comment', 'Relation linking an Observation to the property that was observed. The ObservableProperty should be a property of the FeatureOfInterest (linked by hasFeatureOfInterest) of this Observation.')
# ('https://w3id.org/def/foo#TotalN', 'http://www.w3.org/2000/01/rdf-schema#range', 'http://www.w3.org/2001/XMLSchema#double')
# ('https://w3id.org/def/foo#Site', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/sosa/observedProperty')
# ('https://w3id.org/def/foo#MalayopythonReticulatus', 'http://www.w3.org/2000/01/rdf-schema#label', 'Malayopython reticulatus')
# ('https://w3id.org/def/foo#isObservedBy', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2002/07/owl#ObjectProperty')
# ('https://w3id.org/def/foo#SoilObservation', 'https://w3id.org/def/foo#Sand', '20.66')
# ('https://w3id.org/def/foo#Dara', 'https://w3id.org/def/foo#observes', 'https://w3id.org/def/foo#GPSObservation')
# ('https://w3id.org/def/foo#madeBySensor', 'http://www.w3.org/2000/01/rdf-schema#isDefinedBy', 'http://www.w3.org/ns/sosa/')
# ('https://w3id.org/def/foo#HDOP', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2002/07/owl#DatatypeProperty')
# ('https://w3id.org/def/foo#isFeatureOfInterestOf', 'http://www.w3.org/2000/01/rdf-schema#domain', 'https://w3id.org/def/foo#FeatureOfInterest')
# ('https://w3id.org/def/foo#Altitude', 'http://www.w3.org/2000/01/rdf-schema#range', 'http://www.w3.org/2001/XMLSchema#double')
# ('https://w3id.org/def/foo#LocalTime', 'http://www.w3.org/2000/01/rdf-schema#label', 'Local Time')
# ('https://w3id.org/def/foo#madeObservation', 'http://www.w3.org/2000/01/rdf-schema#label', 'made observation')
# ('https://w3id.org/def/foo#Liun', 'http://www.w3.org/2000/01/rdf-schema#label', 'Liun')
# ('https://w3id.org/def/foo#Seri', 'https://w3id.org/def/foo#hasFeatureOfInterest', 'https://w3id.org/def/foo#ElephasMaximus')
# ('https://w3id.org/def/foo#Horizon', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/sosa/observedProperty')
# ('https://w3id.org/def/foo#GPSObservation', 'https://w3id.org/def/foo#madeBySensor', 'https://w3id.org/def/foo#Maliau')
# ('https://w3id.org/def/foo#Jasper', 'https://w3id.org/def/foo#hasFeatureOfInterest', 'https://w3id.org/def/foo#ElephasMaximus')
# ('https://w3id.org/def/foo#observedProperty', 'http://www.w3.org/2000/01/rdf-schema#range', 'https://w3id.org/def/foo#ObservableProperty')
# ('https://w3id.org/def/foo#ObservableProperty', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/sosa/ObservableProperty')
# ('https://w3id.org/def/foo#lianas', 'https://w3id.org/def/foo#observes', 'https://w3id.org/def/foo#TreeObservation')
# ('https://w3id.org/def/foo#madeBySensor', 'http://www.w3.org/2000/01/rdf-schema#label', 'made by sensor')
# ('https://w3id.org/def/foo#isObservedBy', 'http://www.w3.org/2002/07/owl#inverseOf', 'https://w3id.org/def/foo#observes')
# ('https://w3id.org/def/foo#Count', 'http://www.w3.org/2004/02/skos/core#definition', 'Observation count per data set.')
# ('https://w3id.org/def/foo#Direction', 'http://www.w3.org/2000/01/rdf-schema#label', 'Direction')
# ('https://w3id.org/def/foo#GPSObservation', 'https://w3id.org/def/foo#Longitude', '566.222302')
# ('https://w3id.org/def/foo#', 'http://purl.org/vocab/vann/preferredNamespaceUri', 'https://w3id.org/def/foo#')
# ('https://w3id.org/def/foo#Bikang1', 'http://www.w3.org/2000/01/rdf-schema#label', 'Bikang 1')
# ('https://w3id.org/def/foo#Speed', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2002/07/owl#DatatypeProperty')
# ('https://w3id.org/def/foo#lianasObservation', 'https://w3id.org/def/foo#treeNLianas', '3')
# ('https://w3id.org/def/foo#ElephasMaximus', 'http://www.w3.org/2004/02/skos/core#definition', 'Elephas maximus, commonly known as the Asian elephant, is a species of large mammal native to various regions in South and Southeast Asia, including India, Sri Lanka, Thailand, and parts of Indonesia. It is distinguished by its smaller ears compared to its African relatives, and it has a prominent domed head with two hemispherical bulges. The Asian elephant is classified as Endangered due to significant threats from habitat loss, fragmentation, and poaching. This species plays a crucial ecological role, aiding in forest maintenance through seed dispersal and the creation of clearings in dense vegetation.')
# ('https://github.com/Naeima', 'http://xmlns.com/foaf/0.1/affiliation', 'Cardiff University')
# ('https://w3id.org/def/foo#TotalC', 'http://www.w3.org/2002/07/owl#sameAs', 'http://www.w3.org/ns/sosa/observedProperty')
# ('https://w3id.org/def/foo#GPSObservation', 'https://w3id.org/def/foo#madeBySensor', 'https://w3id.org/def/foo#Puteri')
# ('https://w3id.org/def/foo#ManisJavanica', 'http://www.w3.org/2004/02/skos/core#definition', 'Sunda pangolin aka Manis Javanica is a mammal distinguished by its protective armor of keratin scales, which cover its body except for its belly and face. Native to Southeast Asia, including Malaysia, Thailand, Indonesia, and Vietnam, this species is adapted to various habitats, ranging from primary and secondary forests to wetlands, mangroves, and grasslands. Characterized by its elongated body, small head, and long, prehensile tail, the Sunda pangolin is primarily nocturnal and has a diet mainly consisting of ants and termites, which it extracts using its long, sticky tongue. It plays a vital role in its ecosystem by controlling insect populations.')
# ('https://w3id.org/def/foo#Maliau', 'http://www.w3.org/2000/01/rdf-schema#label', 'Maliau')
# ('https://w3id.org/def/foo#Observation', 'http://www.w3.org/2004/02/skos/core#definition', 'Act of carrying out an (Observation) Procedure to estimate or calculate a value of a property of a FeatureOfInterest (e.g., Elephant). Observation can be seen as a placeholder that links relevant information together. In our ontology, observation can be considered an ID for each data record.')

# %%
 #Retrieve labels for all classes

from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?class ?label
WHERE {
  # ?class rdf:type owl:Class .
  # ?class rdfs:label ?label .
}

"""
# Execute the query
result = g.query(query)

# Print the results
for row in result:
    print(row)
# Out:
# (rdflib.term.URIRef('https://w3id.org/def/foo#Sensor'), rdflib.term.Literal('Sensor', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Observation'), rdflib.term.Literal('Observation', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#ObservableProperty'), rdflib.term.Literal('Observable Property', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#FeatureOfInterest'), rdflib.term.Literal('Feature of Interest', lang='en'))

# %%
#Retrieve labels for all classes (Evalaute Latency)
import time
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?class ?label
WHERE {
  # ?class rdf:type owl:Class .
  # ?class rdfs:label ?label .
}
"""

# Measure query execution time
start_time = time.time()
result = g.query(query)
end_time = time.time()
latency = end_time - start_time

# Define the expected results
expected_classes = set([
    ('https://w3id.org/def/foo#Sensor', 'Sensor'),
    ('https://w3id.org/def/foo#Observation', 'Observation'),
    ('https://w3id.org/def/foo#ObservableProperty', 'Observable Property'),
    ('https://w3id.org/def/foo#FeatureOfInterest', 'Feature of Interest')
])

# Retrieve the actual results
retrieved_classes = set((str(row[0]), str(row[1])) for row in result)

# Calculate precision and recall
true_positives = len(expected_classes & retrieved_classes)
precision = true_positives / len(retrieved_classes) if retrieved_classes else 0
recall = true_positives / len(expected_classes) if expected_classes else 0

# Print the results
print(f"Latency: {latency} seconds")
print(f"Precision: {precision}")
print(f"Recall: {recall}")

# Print the retrieved classes
for cls in retrieved_classes:
    print(cls)
# Out:
# Latency: 0.007107257843017578 seconds
# Precision: 1.0
# Recall: 1.0
# ('https://w3id.org/def/foo#Observation', 'Observation')
# ('https://w3id.org/def/foo#Sensor', 'Sensor')
# ('https://w3id.org/def/foo#FeatureOfInterest', 'Feature of Interest')
# ('https://w3id.org/def/foo#ObservableProperty', 'Observable Property')

# %%
#Retrieve instances with specific properties
# Assuming we are interested in instances of a class Jasmin with a property YourProperty
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX foo: <https://w3id.org/def/foo#>

SELECT *
WHERE {
  # ?instance rdf:type foo:Observation ;
            foo:madeBySensor  foo:Jasmin ;
            foo:hasFeatureOfInterest ?FeatureOfInterest .
}

"""
# Execute the query
result = g.query(query)

# Print the results
for row in result:
    print(row)
# Out:
# (rdflib.term.URIRef('https://w3id.org/def/foo#GPSObservation'), rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'))

# %%
#Retrieve instances with specific properties
# Assuming we are interested in instances of a class Jasmin with a property YourProperty  (Evaluate Latency)
import time
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX foo: <https://w3id.org/def/foo#>

SELECT *
WHERE {
  # ?instance rdf:type foo:Observation ;
            foo:madeBySensor  foo:Jasmin ;
            foo:hasFeatureOfInterest ?FeatureOfInterest .
}
"""

# Measure query execution time
start_time = time.time()
result = g.query(query)
end_time = time.time()
latency = end_time - start_time

# Define the expected results
expected_results = set([
    ('https://w3id.org/def/foo#GPSObservation', 'https://w3id.org/def/foo#ElephasMaximus')
])

# Retrieve the actual results
retrieved_results = set((str(row.instance), str(row.FeatureOfInterest)) for row in result)

# Calculate precision and recall
true_positives = len(expected_results & retrieved_results)
precision = true_positives / len(retrieved_results) if retrieved_results else 0
recall = true_positives / len(expected_results) if expected_results else 0

# Print the results
print(f"Latency: {latency} seconds")
print(f"Precision: {precision}")
print(f"Recall: {recall}")

# Print the retrieved instances
for instance in retrieved_results:
    print(instance)
# Out:
# Latency: 0.00806570053100586 seconds
# Precision: 1.0
# Recall: 1.0
# ('https://w3id.org/def/foo#GPSObservation', 'https://w3id.org/def/foo#ElephasMaximus')

# %%
#Example to retrieve all instances and their labels
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX foo: <https://w3id.org/def/foo#>

SELECT ?instance ?label
WHERE {
  # ?instance rdf:type foo:Sensor .
  # ?instance rdfs:label ?label .
}

"""
# Execute the query
result = g.query(query)

# Print the results
for row in result:
    print(row)
# Out:
# (rdflib.term.URIRef('https://w3id.org/def/foo#Kuma'), rdflib.term.Literal('Kuma', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Jasmin'), rdflib.term.Literal('Jasmin', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Putut'), rdflib.term.Literal('Putut', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Bikang1'), rdflib.term.Literal('Bikang 1', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Bikang2'), rdflib.term.Literal('Bikang 2', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Sejati'), rdflib.term.Literal('Sejati', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Umas2'), rdflib.term.Literal('Umas2', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Ita'), rdflib.term.Literal('Ita', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Abaw'), rdflib.term.Literal('Abaw', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Liun'), rdflib.term.Literal('Liun', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Dara'), rdflib.term.Literal('Dara', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Jasper'), rdflib.term.Literal('Jasper', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Guli'), rdflib.term.Literal('Guli', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Maliau'), rdflib.term.Literal('Maliau', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Tunglap'), rdflib.term.Literal('Tunglap', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Seri'), rdflib.term.Literal('Seri', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Puteri'), rdflib.term.Literal('Puteri', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Tulid'), rdflib.term.Literal('Tulid', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Kasih'), rdflib.term.Literal('Kasih', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Aqeela'), rdflib.term.Literal('Aqeela', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Merotai'), rdflib.term.Literal('Merotai', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#Binbingan'), rdflib.term.Literal('Binbingan', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#SoilSensor'), rdflib.term.Literal('Soil Sensor', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#CameraTrap'), rdflib.term.Literal('Camera Trap', lang='en'))
# (rdflib.term.URIRef('https://w3id.org/def/foo#lianas'), rdflib.term.Literal('lianas', lang='en'))

# %%
#Example to retrieve all instances and their labels (Evaluate Latency)
import time
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX foo: <https://w3id.org/def/foo#>

SELECT ?instance ?label
WHERE {
  # ?instance rdf:type foo:Sensor .
  # ?instance rdfs:label ?label .
}
"""

# Measure query execution time
start_time = time.time()
result = g.query(query)
end_time = time.time()
latency = end_time - start_time

# Define the expected results
expected_results = set([
    ('https://w3id.org/def/foo#Kuma', 'Kuma'),
    ('https://w3id.org/def/foo#Jasmin', 'Jasmin'),
    ('https://w3id.org/def/foo#Putut', 'Putut'),
    ('https://w3id.org/def/foo#Bikang1', 'Bikang 1'),
    ('https://w3id.org/def/foo#Bikang2', 'Bikang 2'),
    ('https://w3id.org/def/foo#Sejati', 'Sejati'),
    ('https://w3id.org/def/foo#Umas2', 'Umas2'),
    ('https://w3id.org/def/foo#Ita', 'Ita'),
    ('https://w3id.org/def/foo#Abaw', 'Abaw'),
    ('https://w3id.org/def/foo#Liun', 'Liun'),
    ('https://w3id.org/def/foo#Dara', 'Dara'),
    ('https://w3id.org/def/foo#Jasper', 'Jasper'),
    ('https://w3id.org/def/foo#Guli', 'Guli'),
    ('https://w3id.org/def/foo#Maliau', 'Maliau'),
    ('https://w3id.org/def/foo#Tunglap', 'Tunglap'),
    ('https://w3id.org/def/foo#Seri', 'Seri'),
    ('https://w3id.org/def/foo#Puteri', 'Puteri'),
    ('https://w3id.org/def/foo#Tulid', 'Tulid'),
    ('https://w3id.org/def/foo#Kasih', 'Kasih'),
    ('https://w3id.org/def/foo#Aqeela', 'Aqeela'),
    ('https://w3id.org/def/foo#Merotai', 'Merotai'),
    ('https://w3id.org/def/foo#Binbingan', 'Binbingan'),
    ('https://w3id.org/def/foo#SoilSensor', 'Soil Sensor'),
    ('https://w3id.org/def/foo#CameraTrap', 'Camera Trap'),
    ('https://w3id.org/def/foo#lianas', 'lianas')
])

# Retrieve the actual results
retrieved_results = set((str(row.instance), str(row.label)) for row in result)

# Calculate precision and recall
true_positives = len(expected_results & retrieved_results)
precision = true_positives / len(retrieved_results) if retrieved_results else 0
recall = true_positives / len(expected_results) if expected_results else 0

# Print the results
print(f"Latency: {latency} seconds")
print(f"Precision: {precision}")
print(f"Recall: {recall}")

# Print the retrieved instances and labels
for instance in retrieved_results:
    print(instance)
# Out:
# Latency: 0.007120370864868164 seconds
# Precision: 1.0
# Recall: 1.0
# ('https://w3id.org/def/foo#Bikang1', 'Bikang 1')
# ('https://w3id.org/def/foo#lianas', 'lianas')
# ('https://w3id.org/def/foo#Guli', 'Guli')
# ('https://w3id.org/def/foo#Jasmin', 'Jasmin')
# ('https://w3id.org/def/foo#Jasper', 'Jasper')
# ('https://w3id.org/def/foo#Merotai', 'Merotai')
# ('https://w3id.org/def/foo#Puteri', 'Puteri')
# ('https://w3id.org/def/foo#Sejati', 'Sejati')
# ('https://w3id.org/def/foo#SoilSensor', 'Soil Sensor')
# ('https://w3id.org/def/foo#Tulid', 'Tulid')
# ('https://w3id.org/def/foo#Seri', 'Seri')
# ('https://w3id.org/def/foo#Putut', 'Putut')
# ('https://w3id.org/def/foo#Kuma', 'Kuma')
# ('https://w3id.org/def/foo#Maliau', 'Maliau')
# ('https://w3id.org/def/foo#Bikang2', 'Bikang 2')
# ('https://w3id.org/def/foo#Aqeela', 'Aqeela')
# ('https://w3id.org/def/foo#Dara', 'Dara')
# ('https://w3id.org/def/foo#CameraTrap', 'Camera Trap')
# ('https://w3id.org/def/foo#Ita', 'Ita')
# ('https://w3id.org/def/foo#Liun', 'Liun')
# ('https://w3id.org/def/foo#Umas2', 'Umas2')
# ('https://w3id.org/def/foo#Abaw', 'Abaw')
# ('https://w3id.org/def/foo#Tunglap', 'Tunglap')
# ('https://w3id.org/def/foo#Kasih', 'Kasih')
# ('https://w3id.org/def/foo#Binbingan', 'Binbingan')

# %%
#Example all instances of Class feature of interest and their labels and definition.
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX foo: <https://w3id.org/def/foo#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
SELECT *
WHERE {
  # ?FeatureOfInterest rdf:type foo:FeatureOfInterest;
   rdfs:label ?label ;
   skos:definition  ?definition .
}

"""
# Execute the query
result = g.query(query)

# Print the results
for row in result:
    print(row)
# Out:
# (rdflib.term.Literal('A dataset describing soil properties from organic and mineral soil across various land uses in Sabah, Malaysia, sampled and measured at the Forest Research Centre Sabah Malaysia.', lang='en'), rdflib.term.Literal('Soil', lang='en'), rdflib.term.URIRef('https://w3id.org/def/foo#Soil'))
# (rdflib.term.Literal('Elephas maximus, commonly known as the Asian elephant, is a species of large mammal native to various regions in South and Southeast Asia, including India, Sri Lanka, Thailand, and parts of Indonesia. It is distinguished by its smaller ears compared to its African relatives, and it has a prominent domed head with two hemispherical bulges. The Asian elephant is classified as Endangered due to significant threats from habitat loss, fragmentation, and poaching. This species plays a crucial ecological role, aiding in forest maintenance through seed dispersal and the creation of clearings in dense vegetation.', lang='en'), rdflib.term.Literal('Asian Elephant', lang='en'), rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'))
# (rdflib.term.Literal('Elephas maximus, commonly known as the Asian elephant, is a species of large mammal native to various regions in South and Southeast Asia, including India, Sri Lanka, Thailand, and parts of Indonesia. It is distinguished by its smaller ears compared to its African relatives, and it has a prominent domed head with two hemispherical bulges. The Asian elephant is classified as Endangered due to significant threats from habitat loss, fragmentation, and poaching. This species plays a crucial ecological role, aiding in forest maintenance through seed dispersal and the creation of clearings in dense vegetation.', lang='en'), rdflib.term.Literal('Elephas maximus', lang='la'), rdflib.term.URIRef('https://w3id.org/def/foo#ElephasMaximus'))
# (rdflib.term.Literal('Nasalis larvatus, aka the proboscis monkey, is a primate species endemic to the island of Borneo. Characterized by its large, pendulous nose in males, this arboreal monkey primarily inhabits mangrove forests, riverine, and coastal areas, and is known for its distinct vocalizations and swimming abilities.', lang='en'), rdflib.term.Literal('Nasalis larvatus', lang='la'), rdflib.term.URIRef('https://w3id.org/def/foo#Nasalislarvatus'))
# (rdflib.term.Literal('Nasalis larvatus, aka the proboscis monkey, is a primate species endemic to the island of Borneo. Characterized by its large, pendulous nose in males, this arboreal monkey primarily inhabits mangrove forests, riverine, and coastal areas, and is known for its distinct vocalizations and swimming abilities.', lang='en'), rdflib.term.Literal('Proboscis Monkey', lang='en'), rdflib.term.URIRef('https://w3id.org/def/foo#Nasalislarvatus'))
# (rdflib.term.Literal('Sunda pangolin aka Manis Javanica is a mammal distinguished by its protective armor of keratin scales, which cover its body except for its belly and face. Native to Southeast Asia, including Malaysia, Thailand, Indonesia, and Vietnam, this species is adapted to various habitats, ranging from primary and secondary forests to wetlands, mangroves, and grasslands. Characterized by its elongated body, small head, and long, prehensile tail, the Sunda pangolin is primarily nocturnal and has a diet mainly consisting of ants and termites, which it extracts using its long, sticky tongue. It plays a vital role in its ecosystem by controlling insect populations.', lang='en'), rdflib.term.Literal('Manis javanica', lang='la'), rdflib.term.URIRef('https://w3id.org/def/foo#ManisJavanica'))
# (rdflib.term.Literal('Sunda pangolin aka Manis Javanica is a mammal distinguished by its protective armor of keratin scales, which cover its body except for its belly and face. Native to Southeast Asia, including Malaysia, Thailand, Indonesia, and Vietnam, this species is adapted to various habitats, ranging from primary and secondary forests to wetlands, mangroves, and grasslands. Characterized by its elongated body, small head, and long, prehensile tail, the Sunda pangolin is primarily nocturnal and has a diet mainly consisting of ants and termites, which it extracts using its long, sticky tongue. It plays a vital role in its ecosystem by controlling insect populations.', lang='en'), rdflib.term.Literal('Sunda Pangolin', lang='en'), rdflib.term.URIRef('https://w3id.org/def/foo#ManisJavanica'))
# (rdflib.term.Literal('Malayopython reticulatus, aka the reticulated python, is a large snake species native to Southeast Asia. Renowned for its impressive length, it is the longest snake in the world, often exceeding 6 meters. It inhabits various environments, including rainforests, woodlands, and plantations, demonstrating adaptability. As a generalist predator, it feeds on many animals, contributing to its ecological significance.', lang='en'), rdflib.term.Literal('Malayopython reticulatus', lang='la'), rdflib.term.URIRef('https://w3id.org/def/foo#MalayopythonReticulatus'))
# (rdflib.term.Literal('Malayopython reticulatus, aka the reticulated python, is a large snake species native to Southeast Asia. Renowned for its impressive length, it is the longest snake in the world, often exceeding 6 meters. It inhabits various environments, including rainforests, woodlands, and plantations, demonstrating adaptability. As a generalist predator, it feeds on many animals, contributing to its ecological significance.', lang='en'), rdflib.term.Literal('Reticulated Python', lang='en'), rdflib.term.URIRef('https://w3id.org/def/foo#MalayopythonReticulatus'))
# (rdflib.term.Literal('Woody climbing plants found in tropical forests, commonly observed in forest plots.', lang='en'), rdflib.term.Literal('Lianas', lang='en'), rdflib.term.URIRef('https://w3id.org/def/foo#Lianas'))
# (rdflib.term.Literal('Image generated by motion-activated wildlife cameras.', lang='en'), rdflib.term.Literal('Camera Trap Image', lang='en'), rdflib.term.URIRef('https://w3id.org/def/foo#Image'))

# %%
#Example all instances of Class feature of interest and their labels and definition. (Evaluate Latency)
import time
from rdflib import Graph

# Load the ontology
ontology_url = "https://naeima.github.io/foo_html/index.ttl"
g = Graph()
g.parse(ontology_url, format="turtle")

# Define a SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX foo: <https://w3id.org/def/foo#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>

SELECT ?FeatureOfInterest ?label ?definition
WHERE {
  # ?FeatureOfInterest rdf:type foo:FeatureOfInterest ;
                     rdfs:label ?label ;
                     skos:definition ?definition .
}
"""

# Measure query execution time
start_time = time.time()
result = g.query(query)
end_time = time.time()
latency = end_time - start_time

# Define the expected results
expected_results = set([
    ('https://w3id.org/def/foo#Soil', 'Soil', 'A dataset describing soil properties from organic and mineral soil across various land uses in Sabah, Malaysia, sampled and measured at the Forest Research Centre Sabah Malaysia.'),
    ('https://w3id.org/def/foo#ElephasMaximus', 'Asian Elephant', 'Elephas maximus, commonly known as the Asian elephant, is a species of large mammal native to various regions in South and Southeast Asia, including India, Sri Lanka, Thailand, and parts of Indonesia. It is distinguished by its smaller ears compared to its African relatives, and it has a prominent domed head with two hemispherical bulges. The Asian elephant is classified as Endangered due to significant threats from habitat loss, fragmentation, and poaching. This species plays a crucial ecological role, aiding in forest maintenance through seed dispersal and the creation of clearings in dense vegetation.'),
    ('https://w3id.org/def/foo#ElephasMaximus', 'Elephas maximus', 'Elephas maximus, commonly known as the Asian elephant, is a species of large mammal native to various regions in South and Southeast Asia, including India, Sri Lanka, Thailand, and parts of Indonesia. It is distinguished by its smaller ears compared to its African relatives, and it has a prominent domed head with two hemispherical bulges. The Asian elephant is classified as Endangered due to significant threats from habitat loss, fragmentation, and poaching. This species plays a crucial ecological role, aiding in forest maintenance through seed dispersal and the creation of clearings in dense vegetation.'),
    ('https://w3id.org/def/foo#Nasalislarvatus', 'Nasalis larvatus', 'Nasalis larvatus, aka the proboscis monkey, is a primate species endemic to the island of Borneo. Characterized by its large, pendulous nose in males, this arboreal monkey primarily inhabits mangrove forests, riverine, and coastal areas, and is known for its distinct vocalizations and swimming abilities.'),
    ('https://w3id.org/def/foo#Nasalislarvatus', 'Proboscis Monkey', 'Nasalis larvatus, aka the proboscis monkey, is a primate species endemic to the island of Borneo. Characterized by its large, pendulous nose in males, this arboreal monkey primarily inhabits mangrove forests, riverine, and coastal areas, and is known for its distinct vocalizations and swimming abilities.'),
    ('https://w3id.org/def/foo#ManisJavanica', 'Manis javanica', 'Sunda pangolin aka Manis Javanica is a mammal distinguished by its protective armor of keratin scales, which cover its body except for its belly and face. Native to Southeast Asia, including Malaysia, Thailand, Indonesia, and Vietnam, this species is adapted to various habitats, ranging from primary and secondary forests to wetlands, mangroves, and grasslands. Characterized by its elongated body, small head, and long, prehensile tail, the Sunda pangolin is primarily nocturnal and has a diet mainly consisting of ants and termites, which it extracts using its long, sticky tongue. It plays a vital role in its ecosystem by controlling insect populations.'),
    ('https://w3id.org/def/foo#ManisJavanica', 'Sunda Pangolin', 'Sunda pangolin aka Manis Javanica is a mammal distinguished by its protective armor of keratin scales, which cover its body except for its belly and face. Native to Southeast Asia, including Malaysia, Thailand, Indonesia, and Vietnam, this species is adapted to various habitats, ranging from primary and secondary forests to wetlands, mangroves, and grasslands. Characterized by its elongated body, small head, and long, prehensile tail, the Sunda pangolin is primarily nocturnal and has a diet mainly consisting of ants and termites, which it extracts using its long, sticky tongue. It plays a vital role in its ecosystem by controlling insect populations.'),
    ('https://w3id.org/def/foo#MalayopythonReticulatus', 'Malayopython reticulatus', 'Malayopython reticulatus, aka the reticulated python, is a large snake species native to Southeast Asia. Renowned for its impressive length, it is the longest snake in the world, often exceeding 6 meters. It inhabits various environments, including rainforests, woodlands, and plantations, demonstrating adaptability. As a generalist predator, it feeds on many animals, contributing to its ecological significance.'),
    ('https://w3id.org/def/foo#MalayopythonReticulatus', 'Reticulated Python', 'Malayopython reticulatus, aka the reticulated python, is a large snake species native to Southeast Asia. Renowned for its impressive length, it is the longest snake in the world, often exceeding 6 meters. It inhabits various environments, including rainforests, woodlands, and plantations, demonstrating adaptability. As a generalist predator, it feeds on many animals, contributing to its ecological significance.'),
    ('https://w3id.org/def/foo#Lianas', 'Lianas', 'Woody climbing plants found in tropical forests, commonly observed in forest plots.'),
    ('https://w3id.org/def/foo#Image', 'Camera Trap Image', 'Image generated by motion-activated wildlife cameras.')
])

# Retrieve the actual results
retrieved_results = set((str(row.FeatureOfInterest), str(row.label), str(row.definition)) for row in result)

# Calculate precision and recall
true_positives = len(expected_results & retrieved_results)
precision = true_positives / len(retrieved_results) if retrieved_results else 0
recall = true_positives / len(expected_results) if expected_results else 0

# Print the results
print(f"Latency: {latency} seconds")
print(f"Precision: {precision}")
print(f"Recall: {recall}")

# Print the retrieved instances
for instance in retrieved_results:
    print(instance)
# Out:
# Latency: 0.02023601531982422 seconds
# Precision: 1.0
# Recall: 1.0
# ('https://w3id.org/def/foo#ElephasMaximus', 'Asian Elephant', 'Elephas maximus, commonly known as the Asian elephant, is a species of large mammal native to various regions in South and Southeast Asia, including India, Sri Lanka, Thailand, and parts of Indonesia. It is distinguished by its smaller ears compared to its African relatives, and it has a prominent domed head with two hemispherical bulges. The Asian elephant is classified as Endangered due to significant threats from habitat loss, fragmentation, and poaching. This species plays a crucial ecological role, aiding in forest maintenance through seed dispersal and the creation of clearings in dense vegetation.')
# ('https://w3id.org/def/foo#MalayopythonReticulatus', 'Malayopython reticulatus', 'Malayopython reticulatus, aka the reticulated python, is a large snake species native to Southeast Asia. Renowned for its impressive length, it is the longest snake in the world, often exceeding 6 meters. It inhabits various environments, including rainforests, woodlands, and plantations, demonstrating adaptability. As a generalist predator, it feeds on many animals, contributing to its ecological significance.')
# ('https://w3id.org/def/foo#ManisJavanica', 'Sunda Pangolin', 'Sunda pangolin aka Manis Javanica is a mammal distinguished by its protective armor of keratin scales, which cover its body except for its belly and face. Native to Southeast Asia, including Malaysia, Thailand, Indonesia, and Vietnam, this species is adapted to various habitats, ranging from primary and secondary forests to wetlands, mangroves, and grasslands. Characterized by its elongated body, small head, and long, prehensile tail, the Sunda pangolin is primarily nocturnal and has a diet mainly consisting of ants and termites, which it extracts using its long, sticky tongue. It plays a vital role in its ecosystem by controlling insect populations.')
# ('https://w3id.org/def/foo#Nasalislarvatus', 'Proboscis Monkey', 'Nasalis larvatus, aka the proboscis monkey, is a primate species endemic to the island of Borneo. Characterized by its large, pendulous nose in males, this arboreal monkey primarily inhabits mangrove forests, riverine, and coastal areas, and is known for its distinct vocalizations and swimming abilities.')
# ('https://w3id.org/def/foo#ElephasMaximus', 'Elephas maximus', 'Elephas maximus, commonly known as the Asian elephant, is a species of large mammal native to various regions in South and Southeast Asia, including India, Sri Lanka, Thailand, and parts of Indonesia. It is distinguished by its smaller ears compared to its African relatives, and it has a prominent domed head with two hemispherical bulges. The Asian elephant is classified as Endangered due to significant threats from habitat loss, fragmentation, and poaching. This species plays a crucial ecological role, aiding in forest maintenance through seed dispersal and the creation of clearings in dense vegetation.')
# ('https://w3id.org/def/foo#Lianas', 'Lianas', 'Woody climbing plants found in tropical forests, commonly observed in forest plots.')
# ('https://w3id.org/def/foo#Image', 'Camera Trap Image', 'Image generated by motion-activated wildlife cameras.')
# ('https://w3id.org/def/foo#ManisJavanica', 'Manis javanica', 'Sunda pangolin aka Manis Javanica is a mammal distinguished by its protective armor of keratin scales, which cover its body except for its belly and face. Native to Southeast Asia, including Malaysia, Thailand, Indonesia, and Vietnam, this species is adapted to various habitats, ranging from primary and secondary forests to wetlands, mangroves, and grasslands. Characterized by its elongated body, small head, and long, prehensile tail, the Sunda pangolin is primarily nocturnal and has a diet mainly consisting of ants and termites, which it extracts using its long, sticky tongue. It plays a vital role in its ecosystem by controlling insect populations.')
# ('https://w3id.org/def/foo#Nasalislarvatus', 'Nasalis larvatus', 'Nasalis larvatus, aka the proboscis monkey, is a primate species endemic to the island of Borneo. Characterized by its large, pendulous nose in males, this arboreal monkey primarily inhabits mangrove forests, riverine, and coastal areas, and is known for its distinct vocalizations and swimming abilities.')
# ('https://w3id.org/def/foo#MalayopythonReticulatus', 'Reticulated Python', 'Malayopython reticulatus, aka the reticulated python, is a large snake species native to Southeast Asia. Renowned for its impressive length, it is the longest snake in the world, often exceeding 6 meters. It inhabits various environments, including rainforests, woodlands, and plantations, demonstrating adaptability. As a generalist predator, it feeds on many animals, contributing to its ecological significance.')
# ('https://w3id.org/def/foo#Soil', 'Soil', 'A dataset describing soil properties from organic and mineral soil across various land uses in Sabah, Malaysia, sampled and measured at the Forest Research Centre Sabah Malaysia.')
